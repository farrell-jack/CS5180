# %%
# Jack Farrell
# Reinforcement Learning
# Problem Set 0
# Problem 3

import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

#-----------------------------
#     Part A
#-----------------------------
class ApartmentEnv(gymnasium.Env):

    #--------------
    # init function
    #--------------
    def __init__(self, T: int, K: int, seed=Node):


    return

    #---------------
    # reset function
    #---------------
    def rest(self, seed=None, options=None):


        return obs, np.info

    #--------------
    # step function
    #--------------
    def step(self, action: int):


        return obs, reward, terminated, truncated, np.info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 17
#       8 import matplotlib.pyplot as plt
#      10 #-----------------------------
#      11 #     Part A
#      12 #-----------------------------
#    (...)     15 # init function
#      16 #--------------
# ---> 17 def __init__(self, T: int, K: int, seed=Node):
#      20   return
#      22 #---------------
#      23 # reset function
#      24 #---------------
#
# NameError: name 'Node' is not defined
